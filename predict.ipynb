# %%
import pandas as pd
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report

# %%
df = pd.read_csv("smote_svm.csv")
df.describe()
# Out:
#            gender         age  ...  Percent Attended       label
# count  136.000000  136.000000  ...        136.000000  136.000000
# mean     0.926471   23.139706  ...          0.465770    0.500000
# std      0.261968    6.013778  ...          0.389344    0.501848
# min      0.000000   11.000000  ...         -0.186117    0.000000
# 25%      1.000000   20.000000  ...          0.065504    0.000000
# 50%      1.000000   21.000000  ...          0.495437    0.500000
# 75%      1.000000   23.000000  ...          0.833333    1.000000
# max      1.000000   44.000000  ...          1.083333    1.000000
#
# [8 rows x 20 columns]

# %%
X = df.drop(columns=['label']) 
y = df['label']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=23)
#splitting the dataset for training and testing

# %%
model = RandomForestClassifier(random_state=23) 
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=23)

# %%
y_pred = model.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy * 100:.2f}%')
# Out:
# Accuracy: 92.68%

# %%
classif_rep = classification_report(y_test, y_pred)
print("\nClassification Report:")
print(classif_rep)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.91      0.93        23
#            1       0.89      0.94      0.92        18
#
#     accuracy                           0.93        41
#    macro avg       0.92      0.93      0.93        41
# weighted avg       0.93      0.93      0.93        41

# %%
cv_scores = cross_val_score(model, X, y, cv=5)  # 5-fold cross-validation
mn = cv_scores.mean()
print(f'\n Cross-validation accuracy: {mn * 100:.2f}%')
# Out:
#  Cross-validation accuracy: 95.58%
